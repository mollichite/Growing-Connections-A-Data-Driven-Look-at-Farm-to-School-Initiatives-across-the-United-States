# %%
import pandas as pd

# %%
df_f2s = pd.read_csv(r"C:\Users\molly\projects\farm_to_school\data\F2S_Census_2023_Public_Use_CSV.csv")
df_f2s
# Out:
# C:\Users\molly\AppData\Local\Temp\ipykernel_16520\3793455094.py:1: DtypeWarning: Columns (6,15,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_f2s = pd.read_csv(r"C:\Users\molly\projects\farm_to_school\data\F2S_Census_2023_Public_Use_CSV.csv")
#             CASEID  RGN                              RGN_TXT  \
# 0      MARO1100174    1  Mid-Atlantic Regional Office (MARO)
# 1      MARO1100179    1  Mid-Atlantic Regional Office (MARO)
# 2      MARO1100181    1  Mid-Atlantic Regional Office (MARO)
# 3      MARO1100182    1  Mid-Atlantic Regional Office (MARO)
# 4      MARO1100183    1  Mid-Atlantic Regional Office (MARO)
# ...            ...  ...                                  ...
# 11257    WRO661310    6        Western Regional Office (WRO)
# 11258    WRO661312    6        Western Regional Office (WRO)
# 11259    WRO661313    6        Western Regional Office (WRO)
# 11260    WRO661315    6        Western Regional Office (WRO)
# ...

# %%
df_schools = pd.read_excel(r"C:\Users\molly\projects\farm_to_school\data\ELSI_excel_export_6389684883881608374860.xls").head(10)
df_schools
# Out:
#                                          ELSI Export  \
# 0                                                NaN
# 1  National Center for Education Statistics - htt...
# 2                                                NaN
# 3  This is a Public School based table with the f...
# 4                                                NaN
# 5                                        School Name
# 6                                     014 FRIDLEY TS
# 7                                              03-MM
# 8                    1 LT CHARLES W. WHITCOMB SCHOOL
# 9  1 SCHOOL                                      ...
#
#                                          Unnamed: 1  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5  State Name [Public School] Latest available year
# ...
